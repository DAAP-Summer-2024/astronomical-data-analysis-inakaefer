# %% [markdown]
# ## Data Analysis for Physics and Astronomy
# ## Sommersemster 2025
# # Assignment 2
#
# Due: **10:00 27. May 2025**
#
# Discussion: **12:00 27. May 2025**
#
# **Online submission** at via github classroom

# %% [markdown]
# # Import and understand scientific data [30 Points]
#
# Describe each of the following file types, then load and visualize the corresponding file's contents.

# %%
# %matplotlib inline

# %% [markdown]
# **a.** FITS: Open and visualise the data in `Data/CII_O1.fits`. **10 points**

# %% [markdown]
# The important package is from the astropy libary: [DOCUMENTATION](https://docs.astropy.org/en/stable/io/fits/)
#
# Every Header Data Unit (HDU) normally has two components: header and data. In astropy these two components are accessed through the two attributes of the HDU, `hdu.header` and `hdu.data`.
#
# What is important to know is that the data contained in the HDU has the shape of the given axes, but it is not specifically those values. For this FITS file, we have Intensity values for axes of 'Frequency', 'RA', 'DEC', and 'Stokes'. The units of the intensity data is given by `BUNIT`: Kelvin. This is typical for radio observational data. The axes can be rebuilt using `CRVAL`, `CRPIX`  and `CDELT` for each axis, and the axes must be linearly-spaced. The units of these axes must be inferred in this case, but typically comments are left for anything that is abnormal. You can find a description of the header labels [here](https://diffractionlimited.com/help/maximdl/FITS_File_Header_Definitions.htm).
#
# Since axes 2, 3, and 4 have length 1, we can simplify our data to two dimensions: frequency and intensity. One super confusing thing about extracting the data (at least I find it super confusing) is that the axes in the extracted numpy array are reversed compared to the header. This is due to the difference between how axes are defined in numpy and in the HDU standard. So to access the first axis in the data you would have to use something like `hdul[0].data[0,0,0,:]`.
#
# Now you just need to plot the data and you are done.
#
# First print the header info.

# %%
from astropy.io import fits
import pprint

# add your code here

hdul = fits.open("Data/CII_01.fits")

hdul.info()

header = hdul[0].header
#print(header)
header

### WHY CANT'T I HAVE TABSTOPS???!!!
# Out:
# Filename: Data/CII_01.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      55   (196, 1, 1, 1)   int32 (rescales to float64)
# SIMPLE  =                    T         /
# BITPIX  =                   32         /
# NAXIS   =                    4         /
# NAXIS1  =                  196         /
# NAXIS2  =                    1         /
# NAXIS3  =                    1         /
# NAXIS4  =                    1         /
# BLOCKED =                    T         /
# BLANK   =           2147483647         / Blanking value
# BSCALE  =  0.880492834199E-007         /
# BZERO   =  0.103385444641E+003         /
# DATAMIN = -0.856989517212E+002         /
# DATAMAX =  0.292469879150E+003         /
# BUNIT   = 'K       '                   /
# CTYPE1  = 'FREQ    '                   /
# CRVAL1  =  0.000000000000E+000         / Offset frequency
# CDELT1  =  0.126790170670E+008         / Frequency resolution
# CRPIX1  =  0.120285079956E+003         /
# CTYPE2  = 'RA---GLS'                   /
# EQUINOX =  0.200000000000E+004         /
# CRVAL2  =  0.567020830000E+002         /
# CDELT2  = -0.477226377822E-003         /
# CRPIX2  =  0.000000000000E+000         /
# CTYPE3  = 'DEC--GLS'                   /
# CRVAL3  =  0.680963890000E+002         /
# CDELT3  = -0.188497195400E-002         /
# CRPIX3  =  0.000000000000E+000         /
# CROTA3  =  0.837167542073E+008         /
# CTYPE4  = 'STOKES  '                   /
# CRVAL4  =      1.0000000000000         /
# CDELT4  =      0.0000000000000         /
# CRPIX4  =      0.0000000000000         /
# TELESCOP= 'SOF-SXFFTS1 '               /
# OBJECT  = 'IC342       '               /
# LINE    = 'CII_U       '               / Line name
# RESTFREQ=  0.190053690000E+013         / Rest frequency
# VELO-LSR=  0.000000000000E+000         / Velocity of reference channel
# DELTAV  = -0.200000000000E+004         / Velocity spacing of channels
# IMAGFREQ=  0.189728674276E+013         / Image frequency
# TSYS    =  0.317318115234E+004         / System temperature
# OBSTIME =  0.244399993896E+003         / Integration time
# SCAN-NUM=  0.100000000000E+001         / Scan number
# TAU-ATM =  0.955695938319E-002         / Atmospheric opacity
# GAINIMAG=  0.500000000000E+000         / Image sideband gain ratio
# BEAMEFF =  0.970000028610E+000         / Beam efficiency
# FORWEFF =  0.970000028610E+000         / Image sideband gain ratio
# ORIGIN  = 'CLASS-Grenoble  '           /
# DATE    = '2014-07-17T00:00:00.000'    / Date written
# TIMESYS = 'UTC             '           /
# DATE-OBS= '2014-04-14T10:13:28.000'    / Date observed
# DATE-RED= '2014-04-28T00:00:00.000'    / Date reduced
# ELEVATIO=  0.000000000000E+000         /  Telescope elevation
# AZIMUTH =  0.000000000000E+000         /  Telescope azimuth
# UT      = ' 10:13:28.000'              /  Universal time at start
# LST     = ' 04:36:47.000'              /  Sideral time at start

# %% [markdown]
# Then access the spectrum data. The `.data` attribute of a table HDU contains the data of the table.

# %%
# add your code here

data = hdul[0].data[0,0,0,:]
#hdul[0].data

print(data)

hdul.close()    #this will need to be moved for the next bit
# Out:
# [ 2.59126161e+02  2.75280401e+02  1.10479011e+02  1.49291535e+02
#   1.39714568e+02  5.55532589e+01  3.50591951e+01  1.94856775e+00
#   2.51690938e+01  9.85093842e+01  7.71789321e+01  2.71806824e+02
#   1.70742780e+02  9.93639602e+01 -2.69653405e+01 -6.85094550e+01
#   1.77778028e+02  7.89352012e+00 -3.47650784e+00  3.23564174e+01
#  -1.13402302e+01  2.44429516e-01 -4.74969203e+00 -1.23747318e+01
#   2.61034587e+01  2.53392755e+01 -2.46041433e+01  3.97537491e+00
#   1.48676976e-01 -3.35360223e-01 -2.19659239e-01 -3.04231632e-01
#   1.81789142e-01  3.87528620e-01  3.33205734e-01 -9.12115352e-02
#   2.45599689e-03  5.88827596e-01 -2.12567317e-02  2.91528134e-01
#  -4.12164477e-02  2.81080558e-01  5.56743926e-02 -5.69272574e-02
#  -1.11633334e-01 -1.62011612e-01 -5.94067252e-02 -7.65601344e-02
#  -2.16962737e-02 -4.79560920e-02 -3.74521647e-02 -3.44429924e-02
#  -4.52850290e-02 -3.59306731e-02  4.94982636e-02  1.16004353e-01
#   8.45180090e-03 -7.05305195e-02 -1.57695084e-01 -8.18797199e-02
#  -3.59419434e-02  6.71250258e-02  6.05122523e-03 -1.06288310e-02
#   3.16235547e-02  7.84967668e-02  6.09150859e-02  7.63892192e-02
#  -4.47327839e-02  4.91150732e-02  1.06875403e-01  1.84122096e-01
#   1.77145775e-01  1.25967305e-01  1.61288451e-01  2.04228326e-01
#   1.46873727e-01  2.16186123e-01  1.03212553e-01  6.68658087e-02
#   1.22811619e-01  2.20344867e-01  2.97208369e-01  2.76380840e-01
#   2.62653604e-01  2.89195180e-01  3.16356623e-01  3.66588387e-01
#   3.31289782e-01  3.74556495e-01  4.10373535e-01  4.23976797e-01
#   6.21218462e-01  5.62162047e-01  4.90381453e-01  6.50622696e-01
#   6.64011822e-01  6.75845646e-01  6.30358682e-01  6.37064515e-01
#   6.58940184e-01  6.59402266e-01  6.15008522e-01  6.02025127e-01
#   6.07491226e-01  4.97199990e-01  5.78751940e-01  4.81297585e-01
#   4.84250405e-01  4.62059168e-01  3.92115635e-01  3.54822185e-01
#   3.08861868e-01  2.41048423e-01  2.41679560e-01  2.14134927e-01
#   1.88156866e-01  2.24571232e-01  1.39863595e-01  1.41880981e-01
#   1.05692021e-01  2.25698263e-01  1.75984933e-01  1.91459067e-01
#   1.00755626e-01  9.33397628e-02  7.69189237e-02  1.85274565e-02
#   7.40366223e-03  4.46520311e-02 -2.47279867e-02  4.49788700e-02
#  -1.05727692e-01 -3.99061944e-03 -4.62317349e-02  5.94274052e-02
#  -1.13275901e-02 -8.46493183e-03  4.02340702e-02 -1.13275901e-02
#  -1.22630257e-02 -2.09411631e-02  3.06317676e-02 -9.46264386e-02
#   1.36586833e-02 -2.64945276e-03  2.30243095e-02  4.89910998e-02
#   1.40193332e-02 -1.34238675e-02 -3.81029451e-03 -6.64844788e-02
#  -8.88109595e-02 -7.10122453e-03 -8.40548894e-02  2.07815182e-02
#   3.86478543e-03  7.28278018e-02  6.20759277e-02  5.47727679e-02
#  -5.64313639e-02 -2.54380161e-02 -1.49791700e-02 -7.76533543e-02
#   1.19005152e-02 -6.00491328e-02  5.17410550e-02  1.30655754e-01
#  -2.37812808e-02 -7.70982117e-03  1.04531179e-01  5.06816460e-02
#   2.90680922e-03  1.31636270e-01  2.47373964e-02  9.49401466e-02
#   8.67720706e-03  2.05335714e-02  1.24682490e-01  2.50755056e-02
#   1.55157404e-01  4.23528882e-02  4.69737146e-02  1.98798935e-02
#   2.02177130e-01  2.40160966e-02  1.08103867e-01  6.90522485e-02
#   7.34589390e-02  1.62032292e-01  6.26281728e-02  2.45071923e-01
#   1.83085228e-01  1.01071194e-01  2.10945430e-01  2.72957563e-02]

# %% [markdown]
# The x axis is frequency as written in the header. Calculate the frequency axis from the header value by using the formula $(i-(crpix1-1))*cdelt1+crval1$

# %%
# add your code here

print(data.shape)    # just checking how many x-values I need

i = 0
frequency = []

for i in range(len(data)):
    frequency.append(((i - (header["CRPIX1"] - 1)) * header["CDELT1"] + header["CRVAL1"]))
    
print(len(frequency))    # checking that the result is reasonable
# Out:
# (196,)
# 196

# %% [markdown]
# Plot the spectrum. Use the frequency values as x-value. Determine the correct Units for the y-axis.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# here your code

data_adjusted = (data * header["BSCALE"]) + header["BZERO"]

plt.plot(frequency, data_adjusted)
plt.xlabel(r"frequency")
plt.ylabel(r"intensity $[K]$")

plt.show()

# %% [markdown]
# **b.** HDF4: Open and visualise the data in `2006001-2006005.s0454pfrt-bsst.hdf`. **10 points**

# %% [markdown]
# You can use pyhdf to obtain extract the HDF4 data. This particular file contains a dictionary with three data objects: one for the two axes, and another containing the data. The axes thus do not need to be rebuilt as with the FITS standard.

# %%
from pyhdf.SD import *
import matplotlib.pyplot as plt
import pprint

file = SD('Data/2006001-2006005.s0454pfrt-bsst.hdf', SDC.READ)

dataset = file.datasets()

# here your code

# "ModuleNotFoundError: No module named 'pyhdf'" - I'm  not doing this again. I'm going home. That computer should have it. If it doesn't, I'm done.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from pyhdf.SD import *
#       2 import matplotlib.pyplot as plt
#       3 import pprint
#
# ModuleNotFoundError: No module named 'pyhdf'

# %% [markdown]
# **c.** HDF5: Open and visualise the data in `3B-HHR.MS.MRG.3IMERG.20141001-S090000-E092959.0540.V05B.HDF5`. **10 points**

# %% [markdown]
# It is worth noting that `pandas` also contains HDF5 functionality, but it is specifically for `pandas` dataframes. It cannot read standard HDF5 files. We instead have to use `h5py`.

# %%
import h5py

hdffilename = "Data/3B-HHR.MS.MRG.3IMERG.20141001-S090000-E092959.0540.V05B.HDF5"
hdf_file = h5py.File(hdffilename,'r')

# %% [markdown]
# To see the top-level meta data,

# %%
topmeta=hdf_file['/']
print(topmeta.attrs.keys())

# %%
fileheader = topmeta.attrs.__getitem__('FileHeader')
print(fileheader.decode('UTF-8'))

# %%
fileinfo = topmeta.attrs.__getitem__('FileInfo')
print(fileinfo.decode('UTF-8'))

# %% [markdown]
# How can we get an overview of the structure?

# %%
print(list(hdf_file.keys()))

# %% [markdown]
# But this does not show the whole tree structures.

# %%
def PrintDataset(name, obj):
    if isinstance(obj,h5py.Dataset):
        print(name)
        print('\t',obj)
hdf_file.visititems(PrintDataset)

# %% [markdown]
# There is a bunch of different data contained in this file. We will examine one of these - 'HQobservationTime' - in more detail.

# %%
meta=hdf_file['Grid/lon']
print(meta.attrs.keys())

fileinfo = meta.attrs.__getitem__('Units')
print(fileinfo.decode('UTF-8'))

meta=hdf_file['Grid/lat']
print(meta.attrs.keys())

fileinfo = meta.attrs.__getitem__('Units')
print(fileinfo.decode('UTF-8'))

meta=hdf_file['Grid/HQobservationTime']
print(meta.attrs.keys())

fileinfo = meta.attrs.__getitem__('DimensionNames')
print(fileinfo.decode('UTF-8'))
fileinfo = meta.attrs.__getitem__('units')
print(fileinfo.decode('UTF-8'))
fileinfo = meta.attrs.__getitem__('Units')
print(fileinfo.decode('UTF-8'))

# %%
hdf_file.close()

# %% [markdown]
# It would be useful if we can store the contents into pandas dataframe.

# %%
import pandas as pd
import numpy as np

def get_df_from_hdf(hdffilename,datasets):
    header = {'filename':hdffilename}

    with h5py.File(hdffilename,'r') as f:
        for colname, dataset in datasets.items():
            ds = f[dataset]
            header[colname] = [ds[()]]

    df = pd.DataFrame(header)
    return df

datasets = {'lat':'Grid/lat', 'lon':'Grid/lon', 'HQobservationTime':'Grid/HQobservationTime'}
df = get_df_from_hdf(hdffilename,datasets)
print(df)

# %% [markdown]
# Visualize the data 'HQobservationTime' as a function of the latitute 'lat' and longitude 'lon'.

# %%
# your code goes here

# %% [markdown]
# # 2. Averaging spectral radio data (DATA EXERCISE) [30 Points]

# %% [markdown]
# In this exercise you will work on a data set of artificial radio observation `radio-map.fits`. It is a map of 5x5
# spectra with 201 measured frequency/velocity channels (channel width is unity). If you number all spectra
# from 1 to 25 we use the following scheme to assign spectra to positions on the map (spectrum 1 is the top
# left spectrum):

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import pprint

# %%
m = fits.open("Data/radio-map.fits")
pprint.pprint(m[0].header)
spectra = m[0].data

# %% [markdown]
# **a.** Compute the total “integrated-intensity” map of the observations, i.e. integrate the spectra over the full spectral range for all positions and plot the 5x5 map in a suitable way. **5 Points**

# %%
# enter your code

# %% [markdown]
# **b.** Compute two channel maps by integrating over the frequency channels 50-100 and 100-150. Compare the two maps. **5 Points**

# %%
# enter your code

# %% [markdown]
# **c.** Compute the average spectrum, by averaging all 25 positions. **5 Points**

# %%
# enter your code

# %% [markdown]
# **d.** Plot every spectrum and overlay the average spectrum. Describe how the emission changes across the map. In particular how the line center position, the peak height and the line widths behave. **15 Points**

# %%
# enter your code
